# %%
from math import *
import numpy as np
import matplotlib.pylab as plt
from scipy.optimize import curve_fit

# %%
time11, pos11 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=460, dtype=float, delimiter=',', unpack=True, usecols=(range(0,2)))
time12, pos12 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=490, dtype=float, delimiter=',', unpack=True, usecols=(range(2,4)))
time13, pos13 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=600, dtype=float, delimiter=',', unpack=True, usecols=(range(4,6)))
time14, pos14 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=593, dtype=float, delimiter=',', unpack=True, usecols=(range(6,8)))
time21, pos21 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=499, dtype=float, delimiter=',', unpack=True, usecols=(range(8,10)))
time22, pos22 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=500, dtype=float, delimiter=',', unpack=True, usecols=(range(10,12)))
time23, pos23 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=593, dtype=float, delimiter=',', unpack=True, usecols=(range(12,14)))
time24, pos24 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=576, dtype=float, delimiter=',', unpack=True, usecols=(range(14,16)))
time31, pos31 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=391, dtype=float, delimiter=',', unpack=True, usecols=(range(16,18)))
time32, pos32 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=390, dtype=float, delimiter=',', unpack=True, usecols=(range(18,20)))
time33, pos33 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=433, dtype=float, delimiter=',', unpack=True, usecols=(range(20,22)))
time34, pos34 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=428, dtype=float, delimiter=',', unpack=True, usecols=(range(22,24)))
time41, pos41 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=163, dtype=float, delimiter=',', unpack=True, usecols=(range(24,26)))
time42, pos42 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=170, dtype=float, delimiter=',', unpack=True, usecols=(range(26,28)))
time43, pos43 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=175, dtype=float, delimiter=',', unpack=True, usecols=(range(28,30)))
time44, pos44 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=177, dtype=float, delimiter=',', unpack=True, usecols=(range(30,32)))
time51, pos51 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=103, dtype=float, delimiter=',', unpack=True, usecols=(range(32,34)))
time52, pos52 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=111, dtype=float, delimiter=',', unpack=True, usecols=(range(34,36)))
time53, pos53 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=111, dtype=float, delimiter=',', unpack=True, usecols=(range(36,38)))
time54, pos54 = np.loadtxt('Glycerin.csv', skiprows=3, max_rows=98, dtype=float, delimiter=',', unpack=True, usecols=(range(38,40)))
pos_uncertainty = np.loadtxt('Glycerin.csv', skiprows=3, dtype=float, delimiter=',', unpack=True, usecols=(range(40,41)))

# %%
def model1(x,a,b):
    return x*a+b

# %%
time_start = 10
time_end = 25
plateau_indices = (time11 >= time_start) & (time11 <= time_end)
time11p = time11[plateau_indices]
pos11p = pos11[plateau_indices]
plateau_indices = (time12 >= time_start) & (time12 <= time_end)
time12p = time12[plateau_indices]
pos12p = pos12[plateau_indices]
plateau_indices = (time13 >= time_start) & (time13 <= time_end)
time13p = time13[plateau_indices]
pos13p = pos13[plateau_indices]
time_start = 20
time_end = 30
plateau_indices = (time14 >= time_start) & (time14 <= time_end)
time14p = time14[plateau_indices]
pos14p = pos14[plateau_indices]
popt11,pcov11=curve_fit(model1,time11p,pos11p,sigma=(0*pos11p+0.000001),absolute_sigma=True)
popt12,pcov12=curve_fit(model1,time12p,pos12p,sigma=(0*pos12p+0.000001),absolute_sigma=True)
popt13,pcov13=curve_fit(model1,time13p,pos13p,sigma=(0*pos13p+0.000001),absolute_sigma=True)
popt14,pcov14=curve_fit(model1,time14p,pos14p,sigma=(0*pos14p+0.000001),absolute_sigma=True)
plt.plot(time11,pos11,marker='.',linewidth=0,color='b')
plt.plot(time12,pos12,marker='.',linewidth=0,color='r')
plt.plot(time13,pos13,marker='.',linewidth=0,color='g')
plt.plot(time14,pos14,marker='.',linewidth=0,color='y')
plt.plot(time11p,model1(time11p,popt11[0],popt11[1]),color='b',label='Trendline, v='+str(np.round(popt11[0],6))+'m/s')
plt.plot(time12p,model1(time12p,popt12[0],popt12[1]),color='r',label='Trendline, v='+str(np.round(popt12[0],6))+'m/s')
plt.plot(time13p,model1(time13p,popt13[0],popt13[1]),color='g',label='Trendline, v='+str(np.round(popt13[0],6))+'m/s')
plt.plot(time14p,model1(time14p,popt14[0],popt14[1]),color='y',label='Trendline, v='+str(np.round(popt14[0],6))+'m/s')
plt.errorbar(time11,pos11,yerr=0.000001,marker='o',ls='',lw=1,color='b',ms=1)
plt.errorbar(time12,pos12,yerr=0.000001,marker='o',ls='',lw=1,color='r',ms=1)
plt.errorbar(time13,pos13,yerr=0.000001,marker='o',ls='',lw=1,color='g',ms=1)
plt.errorbar(time14,pos14,yerr=0.000001,marker='o',ls='',lw=1,color='y',ms=1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.grid()
plt.legend()
plt.show()

# %%
popt21,pcov21=curve_fit(model1,time21,pos21,sigma=(0*pos21+0.000001),absolute_sigma=True)
popt22,pcov22=curve_fit(model1,time22,pos22,sigma=(0*pos22+0.000001),absolute_sigma=True)
popt23,pcov24=curve_fit(model1,time23,pos23,sigma=(0*pos23+0.000001),absolute_sigma=True)
popt24,pcov24=curve_fit(model1,time24,pos24,sigma=(0*pos24+0.000001),absolute_sigma=True)
plt.plot(time21,pos21,marker='.',linewidth=0,color='b')
plt.plot(time22,pos22,marker='.',linewidth=0,color='r')
plt.plot(time23,pos23,marker='.',linewidth=0,color='g')
plt.plot(time24,pos24,marker='.',linewidth=0,color='y')
plt.plot(time21,model1(time21,popt21[0],popt21[1]),color='b',label='Trendline, v='+str(np.round(popt21[0],6))+'m/s')
plt.plot(time22,model1(time22,popt22[0],popt22[1]),color='r',label='Trendline, v='+str(np.round(popt22[0],6))+'m/s')
plt.plot(time23,model1(time23,popt23[0],popt23[1]),color='g',label='Trendline, v='+str(np.round(popt23[0],6))+'m/s')
plt.plot(time24,model1(time24,popt24[0],popt24[1]),color='y',label='Trendline, v='+str(np.round(popt24[0],6))+'m/s')
plt.errorbar(time21,pos21,yerr=0.000001,marker='o',ls='',lw=1,color='b',ms=1)
plt.errorbar(time22,pos22,yerr=0.000001,marker='o',ls='',lw=1,color='r',ms=1)
plt.errorbar(time23,pos23,yerr=0.000001,marker='o',ls='',lw=1,color='g',ms=1)
plt.errorbar(time24,pos24,yerr=0.000001,marker='o',ls='',lw=1,color='y',ms=1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.grid()
plt.legend()
plt.show()

# %%
popt31,pcov31=curve_fit(model1,time31,pos31,sigma=(0*pos31+0.000001),absolute_sigma=True)
popt32,pcov32=curve_fit(model1,time32,pos32,sigma=(0*pos32+0.000001),absolute_sigma=True)
popt33,pcov34=curve_fit(model1,time33,pos33,sigma=(0*pos33+0.000001),absolute_sigma=True)
popt34,pcov34=curve_fit(model1,time34,pos34,sigma=(0*pos34+0.000001),absolute_sigma=True)
plt.plot(time31,pos31,marker='.',linewidth=0,color='b')
plt.plot(time32,pos32,marker='.',linewidth=0,color='r')
plt.plot(time33,pos33,marker='.',linewidth=0,color='g')
plt.plot(time34,pos34,marker='.',linewidth=0,color='y')
plt.plot(time31,model1(time31,popt31[0],popt31[1]),color='b',label='Trendline, v='+str(np.round(popt31[0],6))+'m/s')
plt.plot(time32,model1(time32,popt32[0],popt32[1]),color='r',label='Trendline, v='+str(np.round(popt32[0],6))+'m/s')
plt.plot(time33,model1(time33,popt33[0],popt33[1]),color='g',label='Trendline, v='+str(np.round(popt33[0],6))+'m/s')
plt.plot(time34,model1(time34,popt34[0],popt34[1]),color='y',label='Trendline, v='+str(np.round(popt34[0],6))+'m/s')
plt.errorbar(time31,pos31,yerr=0.000001,marker='o',ls='',lw=1,color='b',ms=1)
plt.errorbar(time32,pos32,yerr=0.000001,marker='o',ls='',lw=1,color='r',ms=1)
plt.errorbar(time33,pos33,yerr=0.000001,marker='o',ls='',lw=1,color='g',ms=1)
plt.errorbar(time34,pos34,yerr=0.000001,marker='o',ls='',lw=1,color='y',ms=1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.grid()
plt.legend()
plt.show()

# %%
time_start = 4
time_end = 8
plateau_indices = (time41 >= time_start) & (time41 <= time_end)
time41p = time41[plateau_indices]
pos41p = pos41[plateau_indices]
plateau_indices = (time42 >= time_start) & (time42 <= time_end)
time42p = time42[plateau_indices]
pos42p = pos42[plateau_indices]
plateau_indices = (time43 >= time_start) & (time43 <= time_end)
time43p = time43[plateau_indices]
pos43p = pos43[plateau_indices]
plateau_indices = (time44 >= time_start) & (time44 <= time_end)
time44p = time44[plateau_indices]
pos44p = pos44[plateau_indices]
popt41,pcov41=curve_fit(model1,time41p,pos41p,sigma=(0*pos41p+0.000001),absolute_sigma=True)
popt42,pcov42=curve_fit(model1,time42p,pos42p,sigma=(0*pos42p+0.000001),absolute_sigma=True)
popt43,pcov43=curve_fit(model1,time43p,pos43p,sigma=(0*pos43p+0.000001),absolute_sigma=True)
popt44,pcov44=curve_fit(model1,time44p,pos44p,sigma=(0*pos44p+0.000001),absolute_sigma=True)
plt.plot(time41,pos41,marker='.',linewidth=0,color='b')
plt.plot(time42,pos42,marker='.',linewidth=0,color='r')
plt.plot(time43,pos43,marker='.',linewidth=0,color='g')
plt.plot(time44,pos44,marker='.',linewidth=0,color='y')
plt.plot(time41p,model1(time41p,popt41[0],popt41[1]),color='b',label='Trendline, y(t)='+str(np.round(popt41[0],6))+'ms^-1')
plt.plot(time42p,model1(time42p,popt42[0],popt42[1]),color='r',label='Trendline, y(t)='+str(np.round(popt42[0],6))+'ms^-1')
plt.plot(time43p,model1(time43p,popt43[0],popt43[1]),color='g',label='Trendline, y(t)='+str(np.round(popt43[0],6))+'ms^-1')
plt.plot(time44p,model1(time44p,popt44[0],popt44[1]),color='y',label='Trendline, y(t)='+str(np.round(popt44[0],6))+'ms^-1')
plt.errorbar(time41,pos41,yerr=0.000001,marker='o',ls='',lw=1,color='b',ms=1)
plt.errorbar(time42,pos42,yerr=0.000001,marker='o',ls='',lw=1,color='r',ms=1)
plt.errorbar(time43,pos43,yerr=0.000001,marker='o',ls='',lw=1,color='g',ms=1)
plt.errorbar(time44,pos44,yerr=0.000001,marker='o',ls='',lw=1,color='y',ms=1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.grid()
plt.legend()
plt.show()

# %%
popt01,pcov01=curve_fit(model1,time41,pos41,sigma=(0*pos41+0.000001),absolute_sigma=True)
plt.plot(time41,pos41-model1(time41,popt01[0],popt01[1]),marker='.',linewidth=0,color='b',label='Raw Data (Trial 1)')
plt.errorbar(time41,pos41-model1(time41,popt01[0],popt01[1]),yerr=(0*pos41+0.000001),marker='o',ls='',lw=1,color='b',ms=1)
popt02,pcov02=curve_fit(model1,time42,pos42,sigma=(0*pos42+0.000001),absolute_sigma=True)
plt.plot(time42,pos42-model1(time42,popt02[0],popt02[1]),marker='.',linewidth=0,color='r',label='Raw Data (Trial 2)')
plt.errorbar(time42,pos42-model1(time42,popt02[0],popt02[1]),yerr=(0*pos42+0.000001),marker='o',ls='',lw=1,color='r',ms=1)
popt03,pcov03=curve_fit(model1,time43,pos43,sigma=(0*pos43+0.000001),absolute_sigma=True)
plt.plot(time43,pos43-model1(time43,popt03[0],popt03[1]),marker='.',linewidth=0,color='y',label='Raw Data (Trial 3)')
plt.errorbar(time43,pos43-model1(time43,popt03[0],popt03[1]),yerr=(0*pos43+0.000001),marker='o',ls='',lw=1,color='y',ms=1)
popt04,pcov04=curve_fit(model1,time44,pos44,sigma=(0*pos44+0.000001),absolute_sigma=True)
plt.plot(time44,pos44-model1(time44,popt04[0],popt04[1]),marker='.',linewidth=0,color='g',label='Raw Data (Trial 4)')
plt.errorbar(time44,pos44-model1(time44,popt04[0],popt04[1]),yerr=(0*pos44+0.000001),marker='o',ls='',lw=1,color='g',ms=1)
plt.plot(time41,model1(time41,popt01[0],popt01[1])*0,color='y',label='Relative Trendline')
plt.xlabel('Time (s)')
plt.ylabel('Diff. in position b/w data & trendline (m)')
plt.grid()
plt.legend()
plt.show()

# %%
time_start = 3
time_end = 4
plateau_indices = (time51 >= time_start) & (time51 <= time_end)
time51p = time51[plateau_indices]
pos51p = pos51[plateau_indices]
plateau_indices = (time52 >= time_start) & (time52 <= time_end)
time52p = time52[plateau_indices]
pos52p = pos52[plateau_indices]
plateau_indices = (time53 >= time_start) & (time53 <= time_end)
time53p = time53[plateau_indices]
pos53p = pos53[plateau_indices]
plateau_indices = (time54 >= time_start) & (time54 <= time_end)
time54p = time54[plateau_indices]
pos54p = pos54[plateau_indices]
popt51,pcov51=curve_fit(model1,time51p,pos51p,sigma=(0*pos51p+0.000001),absolute_sigma=True)
popt52,pcov52=curve_fit(model1,time52p,pos52p,sigma=(0*pos52p+0.000001),absolute_sigma=True)
popt53,pcov54=curve_fit(model1,time53p,pos53p,sigma=(0*pos53p+0.000001),absolute_sigma=True)
popt54,pcov54=curve_fit(model1,time54p,pos54p,sigma=(0*pos54p+0.000001),absolute_sigma=True)
plt.plot(time51,pos51,marker='.',linewidth=0,color='b')
plt.plot(time52,pos52,marker='.',linewidth=0,color='r')
plt.plot(time53,pos53,marker='.',linewidth=0,color='g')
plt.plot(time54,pos54,marker='.',linewidth=0,color='y')
plt.plot(time51p,model1(time51p,popt51[0],popt51[1]),color='b',label='Trendline, v='+str(np.round(popt51[0],6))+'m/s')
plt.plot(time52p,model1(time52p,popt52[0],popt52[1]),color='r',label='Trendline, v='+str(np.round(popt52[0],6))+'m/s')
plt.plot(time53p,model1(time53p,popt53[0],popt53[1]),color='g',label='Trendline, v='+str(np.round(popt53[0],6))+'m/s')
plt.plot(time54p,model1(time54p,popt54[0],popt54[1]),color='y',label='Trendline, v='+str(np.round(popt54[0],6))+'m/s')
plt.errorbar(time51,pos51,yerr=0.000001,marker='o',ls='',lw=1,color='b',ms=1)
plt.errorbar(time52,pos52,yerr=0.000001,marker='o',ls='',lw=1,color='r',ms=1)
plt.errorbar(time53,pos53,yerr=0.000001,marker='o',ls='',lw=1,color='g',ms=1)
plt.errorbar(time54,pos54,yerr=0.000001,marker='o',ls='',lw=1,color='y',ms=1)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.grid()
plt.legend()
plt.show()

# %%
def model2(x,a,b):
    return a*x**2+b
avg_v1 = (popt11[0]+popt12[0]+popt13[0]+popt14[0])/4
avg_v2 = (popt21[0]+popt22[0]+popt23[0]+popt24[0])/4
avg_v3 = (popt31[0]+popt32[0]+popt33[0]+popt34[0])/4
avg_v4 = (popt41[0]+popt42[0]+popt43[0]+popt44[0])/4
avg_v5 = (popt51[0]+popt52[0]+popt53[0]+popt54[0])/4
avg_v = np.array([avg_v1, avg_v2, avg_v3, avg_v4, avg_v5])
avg_vu1 = sqrt(((1/3)*((popt11[0]-avg_v1)**2+(popt12[0]-avg_v1)**2+(popt13[0]-avg_v1)**2+(popt14[0]-avg_v1)**2))/4)
avg_vu2 = sqrt(((1/3)*((popt21[0]-avg_v2)**2+(popt22[0]-avg_v2)**2+(popt23[0]-avg_v2)**2+(popt24[0]-avg_v2)**2))/4)
avg_vu3 = sqrt(((1/3)*((popt31[0]-avg_v3)**2+(popt32[0]-avg_v3)**2+(popt33[0]-avg_v3)**2+(popt34[0]-avg_v3)**2))/4)
avg_vu4 = sqrt(((1/3)*((popt41[0]-avg_v4)**2+(popt42[0]-avg_v4)**2+(popt43[0]-avg_v4)**2+(popt44[0]-avg_v4)**2))/4)
avg_vu5 = sqrt(((1/3)*((popt51[0]-avg_v5)**2+(popt52[0]-avg_v5)**2+(popt53[0]-avg_v5)**2+(popt54[0]-avg_v5)**2))/4)
avg_vu = np.array([avg_vu1, avg_vu2, avg_vu3, avg_vu4, avg_vu5])
radii = np.array([0.00155/2, 0.00234/2, 0.00311/2, 0.00471/2, 0.00626/2])
radii_u = np.array([0.00001, 0.00001, 0.00001, 0.00001, 0.00001])
popt1,pcov1=curve_fit(model1,radii,avg_v,sigma=radii_u,absolute_sigma=True)
popt2,pcov2=curve_fit(model2,radii,avg_v,sigma=radii_u, absolute_sigma=True)
plt.plot(radii,avg_v,marker='.',linewidth=0,color='b')
plt.plot(radii,model1(radii,popt1[0],popt1[1]),color='b',label='Trendline, y='+str(np.round(popt1[0],6))+'x+'+str(round(pcov1[0,0],8)))
plt.plot(radii,model2(radii,popt2[0],popt2[1]),color='r',label='Trendline, y='+str(np.round(popt2[0],6))+'x^2+'+str(round(pcov2[0,0],3)))
plt.errorbar(radii,avg_v,xerr=radii_u,marker='o',ls='',lw=1,color='b',ms=1)
plt.errorbar(radii,avg_v,yerr=avg_vu,marker='o',ls='',lw=1,color='b',ms=1)
plt.xlabel('Radius (m)')
plt.ylabel('Velocity (m/s)')
plt.grid()
plt.legend()
plt.show()

# %%
popt001,pcov001=curve_fit(model1,radii,avg_v,sigma=avg_vu,absolute_sigma=True)
plt.plot(radii,avg_v-model1(radii,popt001[0],popt001[1]),marker='.',linewidth=0,color='b',label='Raw Data')
plt.errorbar(radii,avg_v-model1(radii,popt001[0],popt001[1]),yerr=avg_vu,marker='o',ls='',lw=1,color='b',ms=1)
plt.plot(radii,model1(radii,popt001[0],popt001[1])*0,color='y',label='Trendline')
plt.ylabel('Diff. in velocity b/w data & trendline (m/s)')
plt.xlabel('Radius (m)')
plt.grid()
plt.legend()
plt.show()

# %%
diameters = [0.00155, 0.00234, 0.00311, 0.00471, 0.00626]
avg_velocity = [avg_v1, avg_v2, avg_v3, avg_v4, avg_v5]
avg_v_u = [avg_vu1, avg_vu2, avg_vu3, avg_vu4, avg_vu5]
Re1 = diameters[0]*avg_velocity[0]*(1.26*1000)/(9.34/10)
print(Re1)
Re2 = diameters[1]*avg_velocity[1]*(1.26*1000)/(9.34/10)
print(Re2)
Re3 = diameters[2]*avg_velocity[2]*(1.26*1000)/(9.34/10)
print(Re3)
Re4 = diameters[3]*avg_velocity[3]*(1.26*1000)/(9.34/10)
print(Re4)
Re5 = diameters[4]*avg_velocity[4]*(1.26*1000)/(9.34/10)
print(Re5)
Re_u1 = Re1*sqrt((avg_v_u[0]/avg_velocity[0])**2+(0.000001/diameters[0])**2)*(1.26*1000)/(9.34/10)
print(Re_u1)
Re_u2 = Re2*sqrt((avg_v_u[1]/avg_velocity[1])**2+(0.000001/diameters[1])**2)*(1.26*1000)/(9.34/10)
print(Re_u2)
Re_u3 = Re3*sqrt((avg_v_u[2]/avg_velocity[2])**2+(0.000001/diameters[2])**2)*(1.26*1000)/(9.34/10)
print(Re_u3)
Re_u4 = Re4*sqrt((avg_v_u[3]/avg_velocity[3])**2+(0.000001/diameters[3])**2)*(1.26*1000)/(9.34/10)
print(Re_u4)
Re_u5 = Re5*sqrt((avg_v_u[4]/avg_velocity[4])**2+(0.000001/diameters[4])**2)*(1.26*1000)/(9.34/10)
print(Re_u5)
# Out:
# 0.006863833504766591
# 0.023478052038949922
# 0.052707051303337596
# 0.17511889757213145
# 0.38924596742620904
# 0.08812460141230648
# 0.4091534368246365
# 1.0635625488695477
# 0.7926468657862318
# 3.762624541752141

# %%
def chisquaredr(yi,fxi,uyi,nparameters):
    return (1/(len(yi)-nparameters))*(np.sum(((yi-fxi)/(uyi))**2))
print(chisquaredr(avg_v, model1(radii,popt1[0],popt1[1]), avg_vu, 2))
print(chisquaredr(avg_v, model2(radii,popt2[0],popt2[1]), avg_vu, 2))
# Out:
# 2644.386602776913
# 136.21967009529283
